// %% [markdown]
// <h1 style="color:DodgerBlue">HashSet<T></h1>

// %% [markdown]
// `HashSet<T>` в C# — это коллекция, которая хранит уникальные элементы без определенного порядка. Она полезна, когда нужно быстро проверять наличие элемента или добавлять только уникальные элементы. Давайте рассмотрим, как с ней работать на примере классов `Transport`, `Car`, и `Bike`.
//
// ### Создание классов Transport, Car, и Bike
//
// Сначала определим базовый класс `Transport` и его наследники `Car` и `Bike`:
//
// ```csharp
// public class Transport
// {
//     public string Model { get; set; }
//     public string Manufacturer { get; set; }
//
//     public Transport(string model, string manufacturer)
//     {
//         Model = model;
//         Manufacturer = manufacturer;
//     }
//
//     public override bool Equals(object obj)
//     {
//         // Простая проверка равенства базируется на модели и производителе
//         if (obj is Transport transport)
//         {
//             return Model == transport.Model && Manufacturer == transport.Manufacturer;
//         }
//         return false;
//     }
//
//     public override int GetHashCode()
//     {
//         // Создание хеш-кода на основе модели и производителя
//         return HashCode.Combine(Model, Manufacturer);
//     }
//
//     public virtual void DisplayInfo()
//     {
//         Console.WriteLine($"Model: {Model}, Manufacturer: {Manufacturer}");
//     }
// }
//
// public class Car : Transport
// {
//     public int NumberOfDoors { get; set; }
//
//     public Car(string model, string manufacturer, int numberOfDoors)
//         : base(model, manufacturer)
//     {
//         NumberOfDoors = numberOfDoors;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Number of Doors: {NumberOfDoors}");
//     }
// }
//
// public class Bike : Transport
// {
//     public bool HasCarrier { get; set; }
//
//     public Bike(string model, string manufacturer, bool hasCarrier)
//         : base(model, manufacturer)
//     {
//         HasCarrier = hasCarrier;
//     }
//
//     public override void DisplayInfo()
//     {
//         base.DisplayInfo();
//         Console.WriteLine($"Has Carrier: {HasCarrier}");
//     }
// }
// ```
//
// ### Работа с HashSet<T>
//
// Теперь рассмотрим, как использовать `HashSet<T>` для хранения объектов `Transport`.
//
// ```csharp
// using System;
// using System.Collections.Generic;
//
//
// // Создаем HashSet для уникальных объектов транспортных средств
// HashSet<Transport> transportSet = new HashSet<Transport>();
//
// // Добавляем объекты Car и Bike в HashSet
// var car1 = new Car("Model S", "Tesla", 4);
// var car2 = new Car("Model 3", "Tesla", 4);
//  var bike1 = new Bike("Mountain Explorer", "Giant", true);
//
// transportSet.Add(car1);
// transportSet.Add(car2);
// transportSet.Add(bike1);
//
// // Попробуем добавить повторяющийся объект
// var duplicateCar = new Car("Model S", "Tesla", 4);
// bool isAdded = transportSet.Add(duplicateCar);
//
// Console.WriteLine($"Was duplicate car added? {isAdded}"); // false
//
// // Перебираем и выводим информацию обо всех уникальных транспортных средствах
// foreach (var transport in transportSet)
// {
//     transport.DisplayInfo();
//     Console.WriteLine();
// }
//
// ```
//
// ### Объяснения и комментарии:
//
// - **Уникальность объектов**: `HashSet<T>` не допускает дублирования. Если вы пытаетесь добавить элемент, который уже присутствует (определяется методом `Equals` и `GetHashCode`), он не добавляется.
//
// - **Методы `Equals` и `GetHashCode`**: Эти методы переопределены для корректной работы с `HashSet`. `Equals` определяет, когда два объекта считаются равными, а `GetHashCode` возвращает хеш-код, используемый для быстрого поиска элемента.
//
// - **Быстрая проверка на наличие**: Благодаря хешированию, `HashSet` позволяет быстро проверять, существует ли элемент в коллекции (`O(1)` — амортизированное время).
//
// - **Отсутствие порядка**: Элементы в `HashSet` не имеют определенного порядка, в отличие от `List<T>`.
//
// `HashSet<T>` идеально подходит для сценариев, где требуется исключительно уникальность элементов и быстрое выполнение операций поиска.

// %% [markdown]
// <h4 style="color:DodgerBlue">Для проверки напишите пример кода на основе классов `Transport`, `Car`, и `Bike` ниже в блоке с применением  HashSet</h4>
//
// ----

// %%
public class Transport
{
    public string Model { get; set; }
    public string Manufacturer { get; set; }

    public Transport(string model, string manufacturer)
    {
        Model = model;
        Manufacturer = manufacturer;
    }

    public override bool Equals(object obj)
    {
        if (obj is Transport transport)
        {
            return Model == transport.Model && Manufacturer == transport.Manufacturer;
        }
        return false;
    }


    public override int GetHashCode()
    {
        return HashCode.Combine(Model, Manufacturer);
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Model: {Model}, Manufacturer: {Manufacturer}");
    }
}


public class Car : Transport
{
    public int NumberOfDoors { get; set; }

    public Car(string model, string manufacturer, int numberOfDoors)
        : base(model, manufacturer)
    {
        NumberOfDoors = numberOfDoors;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Number of Doors: {NumberOfDoors}");
    }
}


public class Bike : Transport
{
    public bool HasCarrier { get; set; }

    public Bike(string model, string manufacturer, bool hasCarrier)
        : base(model, manufacturer)
    {
        HasCarrier = hasCarrier;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Has Carrier: {HasCarrier}");
    }
}



        HashSet<Transport> transportSet = new HashSet<Transport>();

 
        Car teslaModelS = new Car("Model S", "Tesla", 4);
        Car hondaCivic = new Car("Civic", "Honda", 4);
        Bike giantBike = new Bike("Mountain Bike", "Giant", true);
        Bike trekBike = new Bike("Road Bike", "Trek", false);
        
    
        Console.WriteLine("Добавление элементов:");
        Console.WriteLine($"Tesla добавлена: {transportSet.Add(teslaModelS)}");
        Console.WriteLine($"Honda добавлена: {transportSet.Add(hondaCivic)}");
        Console.WriteLine($"Giant bike добавлен: {transportSet.Add(giantBike)}");
        Console.WriteLine($"Trek bike добавлен: {transportSet.Add(trekBike)}");


        Car teslaDuplicate = new Car("Model S", "Tesla", 2); // Двери не влияют на равенство
        bool added = transportSet.Add(teslaDuplicate);
        Console.WriteLine($"\nДубликат Tesla добавлен: {added}");

   
        Car testCar = new Car("Civic", "Honda", 4);
        bool exists = transportSet.Contains(testCar);
        Console.WriteLine($"Honda Civic в коллекции: {exists}");

   
        Console.WriteLine("\nВсе транспортные средства в HashSet:");
        foreach (var transport in transportSet)
        {
            transport.DisplayInfo();
            Console.WriteLine("---");
        }

 
        bool removed = transportSet.Remove(hondaCivic);
        Console.WriteLine($"\nHonda Civic удалена: {removed}");
        Console.WriteLine($"Элементов после удаления: {transportSet.Count}");

      
        Console.WriteLine("\nДемонстрация уникальности:");
        HashSet<Transport> anotherSet = new HashSet<Transport>
        {
            new Car("Model S", "Tesla", 4),
            new Car("Model 3", "Tesla", 4),
            new Bike("Mountain Bike", "Giant", true)
        };

        Console.WriteLine("Элементы в новом HashSet:");
        foreach (var transport in anotherSet)
        {
            transport.DisplayInfo();
        }
// Out:
// Добавление элементов:
// Tesla добавлена: True
// Honda добавлена: True
// Giant bike добавлен: True
// Trek bike добавлен: True
//
// Дубликат Tesla добавлен: False
// Honda Civic в коллекции: True
//
// Все транспортные средства в HashSet:
// Model: Model S, Manufacturer: Tesla
// Number of Doors: 4
// ---
// Model: Civic, Manufacturer: Honda
// Number of Doors: 4
// ---
// Model: Mountain Bike, Manufacturer: Giant
// Has Carrier: True
// ---
// Model: Road Bike, Manufacturer: Trek
// Has Carrier: False
// ---
//
// Honda Civic удалена: True
// Элементов после удаления: 3
//
// Демонстрация уникальности:
// Элементы в новом HashSet:
// Model: Model S, Manufacturer: Tesla
// Number of Doors: 4
// Model: Model 3, Manufacturer: Tesla
// Number of Doors: 4
// Model: Mountain Bike, Manufacturer: Giant
// Has Carrier: True

// %% [markdown]
// <h4 style="color:Red">Задание:</h4>
//
// ----
//
// Ниже в блоке по примеру создайте базовый класс Animal и производные классы (3-4 например Dog, Cat, Bird и так далее) реализуйте при помощи  HashSet.

// %%
public class Animal
{
    public string Name { get; set; }
    public int Age { get; set; }
    public string Species { get; set; }

    public Animal(string name, int age, string species)
    {
        Name = name;
        Age = age;
        Species = species;
    }


    public override bool Equals(object obj)
    {
        if (obj is Animal animal)
        {
            return Name == animal.Name && Age == animal.Age && Species == animal.Species;
        }
        return false;
    }


    public override int GetHashCode()
    {
        return HashCode.Combine(Name, Age, Species);
    }

    public virtual void DisplayInfo()
    {
        Console.WriteLine($"Вид: {Species}, Имя: {Name}, Возраст: {Age}");
    }

    public virtual void MakeSound()
    {
        Console.WriteLine($"{Name} издает звук");
    }
}


public class Dog : Animal
{
    public string Breed { get; set; }
    public bool IsTrained { get; set; }

    public Dog(string name, int age, string breed, bool isTrained)
        : base(name, age, "Собака")
    {
        Breed = breed;
        IsTrained = isTrained;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Порода: {Breed}, дрессированная: {IsTrained}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Гав! Гав!");
    }

    public void Fetch()
    {
        Console.WriteLine($"{Name} ловит мяч");
    }
}


public class Cat : Animal
{
    public string Color { get; set; }
    public bool IsIndoor { get; set; }

    public Cat(string name, int age, string color, bool isIndoor)
        : base(name, age, "Кошка")
    {
        Color = color;
        IsIndoor = isIndoor;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Цвет: {Color}, дома ли: {IsIndoor}");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} говорит: Мяу! Мяу!");
    }

    public void Purr()
    {
        Console.WriteLine($"{Name} мягко мурлычет");
    }
}


public class Bird : Animal
{
    public double Wingspan { get; set; }
    public bool CanSing { get; set; }

    public Bird(string name, int age, double wingspan, bool canSing)
        : base(name, age, "Птица")
    {
        Wingspan = wingspan;
        CanSing = canSing;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Размах: {Wingspan} см, способность петь: {CanSing}");
    }

    public override void MakeSound()
    {
        if (CanSing)
            Console.WriteLine($"{Name} поет: Чирик-чирик! Какая красота!");
        else
            Console.WriteLine($"{Name} говорит: Чирк! Чирк!");
    }

    public void Fly()
    {
        Console.WriteLine($"{Name} летает, имея {Wingspan} сантиметровый размах крыльев");
    }
}


public class Fish : Animal
{
    public string WaterType { get; set; }
    public double Size { get; set; }

    public Fish(string name, int age, string waterType, double size)
        : base(name, age, "Рыба")
    {
        WaterType = waterType;
        Size = size;
    }

    public override void DisplayInfo()
    {
        base.DisplayInfo();
        Console.WriteLine($"Тип воды: {WaterType}, Размер: {Size} см");
    }

    public override void MakeSound()
    {
        Console.WriteLine($"{Name} издает: Гулп гулп!");
    }

    public void Swim()
    {
        Console.WriteLine($"{Name} плавает в {WaterType} воде");
    }
}


        HashSet<Animal> animalShelter = new HashSet<Animal>();

        Console.WriteLine("=== ДОБАВЛЕНИЕ ЖИВОТНЫХ В ПРИЮТ ===\n");


        Dog dog1 = new Dog("Рекс", 3, "Немецкая овчарка", true);
        Dog dog2 = new Dog("Боди", 2, "Золотой ретривер", false);
        Cat cat1 = new Cat("Вискас", 4, "Серый", true);
        Cat cat2 = new Cat("Луна", 1, "Черная", false);
        Bird bird1 = new Bird("Кеша", 1, 15.5, true);
        Bird bird2 = new Bird("Полина", 5, 25.0, false);
        Fish fish1 = new Fish("Макс", 2, "Свежей", 10.5);

  
        Console.WriteLine($"Добавлен Рекс: {animalShelter.Add(dog1)}");
        Console.WriteLine($"Добавлен Боди: {animalShelter.Add(dog2)}");
        Console.WriteLine($"Добавлен Вискас: {animalShelter.Add(cat1)}");
        Console.WriteLine($"Добавлен Луна: {animalShelter.Add(cat2)}");
        Console.WriteLine($"Добавлен Кеша: {animalShelter.Add(bird1)}");
        Console.WriteLine($"Добавлен Полина: {animalShelter.Add(bird2)}");
        Console.WriteLine($"Добавлен Макс: {animalShelter.Add(fish1)}");

   
        Dog dogDuplicate = new Dog("Рекс", 3, "Немецкая овчарка", true);
        bool duplicateAdded = animalShelter.Add(dogDuplicate);
        Console.WriteLine($"\nДубликат Рекс добавлен: {duplicateAdded}");

       
        Console.WriteLine($"\n=== ВСЕ ЖИВОТНЫЕ В ПРИЮТЕ ({animalShelter.Count}) ===");
        foreach (var animal in animalShelter)
        {
            animal.DisplayInfo();
            animal.MakeSound();
            Console.WriteLine("---");
        }

    
        Console.WriteLine("\n=== ПРОВЕРКА НАЛИЧИЯ ЖИВОТНЫХ ===");
        Cat testCat = new Cat("Вискас", 4, "Серый", true);
        Dog testDog = new Dog("Тоби", 1, "Неизвестно", false);
        
        Console.WriteLine($"Вискас в приюте: {animalShelter.Contains(testCat)}");
        Console.WriteLine($"Тоби в приюте: {animalShelter.Contains(testDog)}");

    
        Console.WriteLine($"\n=== УДАЛЕНИЕ ЖИВОТНОГО ===");
        bool removed = animalShelter.Remove(cat2);
        Console.WriteLine($"Луна удалена: {removed}");
        Console.WriteLine($"Осталось животных: {animalShelter.Count}");

    
        Console.WriteLine($"\n=== ДЕМОНСТРАЦИЯ УНИКАЛЬНОСТИ ===");
        HashSet<Animal> anotherShelter = new HashSet<Animal>
        {
            new Dog("Рекс", 3, "Немецкая овчарка", true),
            new Cat("Царапка", 2, "Белая", true),
            new Bird("Скай", 1, 12.0, true)
        };

        Console.WriteLine("Животные в новом приюте:");
        foreach (var animal in anotherShelter)
        {
            animal.DisplayInfo();
        }

     
        Console.WriteLine($"\n=== ОБЪЕДИНЕНИЕ ПРИЮТОВ ===");
        animalShelter.UnionWith(anotherShelter);
        Console.WriteLine($"После объединения: {animalShelter.Count} животных");

       
        Console.WriteLine($"\n=== СПЕЦИАЛЬНЫЕ ВОЗМОЖНОСТИ ЖИВОТНЫХ ===");
        foreach (var animal in animalShelter)
        {
            animal.DisplayInfo();
            
            if (animal is Dog dog)
                dog.Fetch();
            else if (animal is Cat cat)
                cat.Purr();
            else if (animal is Bird bird)
                bird.Fly();
            else if (animal is Fish fish)
                fish.Swim();
                
            Console.WriteLine("---");
        }
// Out:
// === ДОБАВЛЕНИЕ ЖИВОТНЫХ В ПРИЮТ ===
//
// Добавлен Рекс: True
// Добавлен Боди: True
// Добавлен Вискас: True
// Добавлен Луна: True
// Добавлен Кеша: True
// Добавлен Полина: True
// Добавлен Макс: True
//
// Дубликат Рекс добавлен: False
//
// === ВСЕ ЖИВОТНЫЕ В ПРИЮТЕ (7) ===
// Вид: Собака, Имя: Рекс, Возраст: 3
// Порода: Немецкая овчарка, дрессированная: True
// Рекс говорит: Гав! Гав!
// ---
// Вид: Собака, Имя: Боди, Возраст: 2
// Порода: Золотой ретривер, дрессированная: False
// Боди говорит: Гав! Гав!
// ---
// Вид: Кошка, Имя: Вискас, Возраст: 4
// Цвет: Серый, дома ли: True
// Вискас говорит: Мяу! Мяу!
// ---
// Вид: Кошка, Имя: Луна, Возраст: 1
// Цвет: Черная, дома ли: False
// Луна говорит: Мяу! Мяу!
// ---
// Вид: Птица, Имя: Кеша, Возраст: 1
// Размах: 15.5 см, способность петь: True
// Кеша поет: Чирик-чирик! Какая красота!
// ---
// Вид: Птица, Имя: Полина, Возраст: 5
// Размах: 25 см, способность петь: False
// Полина говорит: Чирк! Чирк!
// ---
// Вид: Рыба, Имя: Макс, Возраст: 2
// Тип воды: Свежей, Размер: 10.5 см
// Макс издает: Гулп гулп!
// ---
//
// === ПРОВЕРКА НАЛИЧИЯ ЖИВОТНЫХ ===
// Вискас в приюте: True
// Тоби в приюте: False
//
// === УДАЛЕНИЕ ЖИВОТНОГО ===
// Луна удалена: True
// Осталось животных: 6
//
// === ДЕМОНСТРАЦИЯ УНИКАЛЬНОСТИ ===
// Животные в новом приюте:
// Вид: Собака, Имя: Рекс, Возраст: 3
// Порода: Немецкая овчарка, дрессированная: True
// Вид: Кошка, Имя: Царапка, Возраст: 2
// Цвет: Белая, дома ли: True
// Вид: Птица, Имя: Скай, Возраст: 1
// Размах: 12 см, способность петь: True
//
// === ОБЪЕДИНЕНИЕ ПРИЮТОВ ===
// После объединения: 8 животных
//
// === СПЕЦИАЛЬНЫЕ ВОЗМОЖНОСТИ ЖИВОТНЫХ ===
// Вид: Собака, Имя: Рекс, Возраст: 3
// Порода: Немецкая овчарка, дрессированная: True
// Рекс ловит мяч
// ---
// Вид: Собака, Имя: Боди, Возраст: 2
// Порода: Золотой ретривер, дрессированная: False
// Боди ловит мяч
// ---
// Вид: Кошка, Имя: Вискас, Возраст: 4
// Цвет: Серый, дома ли: True
// Вискас мягко мурлычет
// ---
// Вид: Кошка, Имя: Царапка, Возраст: 2
// Цвет: Белая, дома ли: True
// Царапка мягко мурлычет
// ---
// Вид: Птица, Имя: Кеша, Возраст: 1
// Размах: 15.5 см, способность петь: True
// Кеша летает, имея 15.5 сантиметровый размах крыльев
// ---
// Вид: Птица, Имя: Полина, Возраст: 5
// Размах: 25 см, способность петь: False
// Полина летает, имея 25 сантиметровый размах крыльев
// ---
// Вид: Рыба, Имя: Макс, Возраст: 2
// Тип воды: Свежей, Размер: 10.5 см
// Макс плавает в Свежей воде
// ---
// Вид: Птица, Имя: Скай, Возраст: 1
// Размах: 12 см, способность петь: True
// Скай летает, имея 12 сантиметровый размах крыльев
// ---
